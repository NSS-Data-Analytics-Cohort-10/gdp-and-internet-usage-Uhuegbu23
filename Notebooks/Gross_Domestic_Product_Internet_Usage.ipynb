# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
print(pd)
# Out:
# <module 'pandas' from '/Users/chiedozieuhuegbu/anaconda3/lib/python3.11/site-packages/pandas/__init__.py'>

# %%
import pandas as pd

# %%
gdp_df=pd.read_csv('../Data/gdp_percapita.csv')

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# print (gdp_df)

# %%
num_columns = gdp_df

# %%
print (num_columns)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2021  1517.016266              NaN
# 1        Afghanistan  2020  1968.341002              NaN
# 2        Afghanistan  2019  2079.921861              NaN
# 3        Afghanistan  2018  2060.698973              NaN
# 4        Afghanistan  2017  2096.093111              NaN
# ...              ...   ...          ...              ...
# 7657        Zimbabwe  1994  2670.106615              NaN
# 7658        Zimbabwe  1993  2458.783255              NaN
# 7659        Zimbabwe  1992  2468.278257              NaN
# 7660        Zimbabwe  1991  2781.787843              NaN
# 7661        Zimbabwe  1990  2704.757299              NaN
#
# [7662 rows x 4 columns]

# %%
num_rows, num_cols = gdp_df.shape

# %% [markdown]
# [7662 rows x 4 columns]

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2021  1517.016266              NaN
# 1        Afghanistan  2020  1968.341002              NaN
# 2        Afghanistan  2019  2079.921861              NaN
# 3        Afghanistan  2018  2060.698973              NaN
# 4        Afghanistan  2017  2096.093111              NaN
# ...              ...   ...          ...              ...
# 7657        Zimbabwe  1994  2670.106615              NaN
# 7658        Zimbabwe  1993  2458.783255              NaN
# 7659        Zimbabwe  1992  2468.278257              NaN
# 7660        Zimbabwe  1991  2781.787843              NaN
# 7661        Zimbabwe  1990  2704.757299              NaN
#
# [7662 rows x 4 columns]

# %%
gdp_df=gdp_df.drop(columns=['Value Footnotes'])
gdp_df.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'GDP_Per_Capita'}, inplace=True)
print(gdp_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7662 non-null   object
#  1   Year            7662 non-null   int64
#  2   GDP_Per_Capita  7662 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 179.7+ KB
# None

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2021     1517.016266
# 1     Afghanistan  2020     1968.341002
# 2     Afghanistan  2019     2079.921861
# 3     Afghanistan  2018     2060.698973
# 4     Afghanistan  2017     2096.093111
# ...           ...   ...             ...
# 7657     Zimbabwe  1994     2670.106615
# 7658     Zimbabwe  1993     2458.783255
# 7659     Zimbabwe  1992     2468.278257
# 7660     Zimbabwe  1991     2781.787843
# 7661     Zimbabwe  1990     2704.757299
#
# [7662 rows x 3 columns]

# %%
gdp_df['Country'].value_counts()
# Out:
# Country
# Least developed countries: UN classification    33
# Middle East & North Africa                      33
# Middle East & North Africa (IDA & IBRD)         33
# Middle income                                   33
# Mongolia                                        33
#                                                 ..
# Kosovo                                          15
# Sint Maarten (Dutch part)                       14
# Turks and Caicos Islands                        12
# Somalia                                         10
# Djibouti                                        10
# Name: count, Length: 242, dtype: int64

# %%
gdp_df['Year'].value_counts()
# Out:
# Year
# 2013    242
# 2016    242
# 2014    242
# 2015    242
# 2020    242
# 2017    242
# 2018    242
# 2019    242
# 2021    241
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 2022    232
# 1999    227
# 1998    226
# 1997    226
# 1996    223
# 1995    223
# 1994    213
# 1993    211
# 1992    210
# 1991    208
# 1990    207
# Name: count, dtype: int64

# %%
gdp_df_2020 = gdp_df[gdp_df['Year'] == 2020]

# %%
gdp_df_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
# Filter the DataFrame for the year 2020, number 8
gdp_df_2020 = gdp_df[gdp_df['Year'] == 2020]

# Plot a histogram of the 'Gdp_per_capital' column
GDP_Per_Capita=gdp_df_2020['GDP_Per_Capita']
GDP_Per_Capita.hist()
# Out:
# <Axes: >

# %%
# Plot a density of the 'Gdp_per_capital' column
GDP_Per_Capita=gdp_df_2020['GDP_Per_Capita']
GDP_Per_Capita.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Plot a box plot of the 'Gdp_per_capital' column
GDP_Per_Capita=gdp_df_2020['GDP_Per_Capita']
sns.boxplot(y=GDP_Per_Capita)
plt.show()

# %%
# Plot a violinplot of the 'Gdp_per_capital' column
GDP_Per_Capita=gdp_df_2020['GDP_Per_Capita']
sns.violinplot(y=GDP_Per_Capita)
plt.show()

# %%
gdp_df.groupby('Country')['Year'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 gdf_df.groupby('Country')['Year'].nunique()
#
# NameError: name 'gdf_df' is not defined

# %%
gdp_df_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 1                     Afghanistan  2020     1968.341002
# 22    Africa Eastern and Southern  2020     3455.023119
# 55     Africa Western and Central  2020     3957.933804
# 88                        Albania  2020    13278.369769
# 121                       Algeria  2020    10844.770764
# ...                           ...   ...             ...
# 7503                     Viet Nam  2020    10450.622382
# 7536           West Bank and Gaza  2020     5402.538773
# 7565                        World  2020    16204.169107
# 7598                       Zambia  2020     3183.650773
# 7631                     Zimbabwe  2020     1990.319419
#
# [242 rows x 3 columns]

# %%
##9. median GDP per capita value in 2020 = 13357.997573370474
gdp_df_2020 = gdp_df[gdp_df['Year'] == 2020]
median_GDP_per_capita_value_2020= gdp_df_2020['GDP_Per_Capita'].median()
print(median_GDP_per_capita_value_2020)
# Out:
# 13357.997573370474

# %%
print (pd)

# %%
#10. create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020
compare_GDP_per_capita_values = [1990, 2000, 2010, 2020]
gdp_df_compared = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]
gdp_decades = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]

## a box plot
gdp_df_pivot = gdp_df_compared.pivot(index='Country', columns='Year', values='GDP_Per_Capita')
gdp_df_pivot.boxplot()
plt.title('gdp_decades')
plt.xlabel('Country')
plt.ylabel('GDP per Capita')
plt.show()

# %%
#10. create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020

compare_GDP_per_capita_values = [1990, 2000, 2010, 2020]
gdp_df_compared = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]
gdp_decades = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]

#A barplot
sns.barplot(data=gdp_decades, x='Year', y= 'GDP_Per_Capita')
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#10. create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020

compare_GDP_per_capita_values = [1990, 2000, 2010, 2020]
gdp_df_compared = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]
gdp_decades = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]

#A scatterplot
sns.scatterplot(data=gdp_decades,x='Year', y='GDP_Per_Capita')
plt.title('gdp_decades')
plt.show()

# %%
#10. create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020

compare_GDP_per_capita_values = [1990, 2000, 2010, 2020]
gdp_df_compared = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]
gdp_decades = gdp_df[gdp_df['Year'].isin(compare_GDP_per_capita_values)]

#A scatterplot with a trend line overlaid
sns.regplot(data=gdp_decades,x='Year', y='GDP_Per_Capita')
plt.title('gdp_decades')
plt.show()


#the gdps seems to be growing from the 1990s to 2020s and have a growing little by little. there seems to be a decline in growth

# %%
#11. Which country was the first to have a GDP per capita greater than $100,000?
gdp_above_100k = gdp_df[gdp_df['GDP_Per_Capita'] > 100000]
gdp_above_100k_sorted = gdp_above_100k.sort_values('Year')
first_country = gdp_above_100k_sorted.iloc[0]
print(first_country)

#United Arab Emirates in 1990
# Out:
# Country           United Arab Emirates
# Year                              1990
# GDP_Per_Capita           105893.626059
# Name: 7302, dtype: object

# %%
#12. Which country had the highest GDP per capita in 2020?
